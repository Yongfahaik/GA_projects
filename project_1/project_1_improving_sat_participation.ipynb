# %% [markdown]
# <div>
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px" width=100>
# </div>
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# *The new format for the SAT was released in March 2016. As an employee of the College Board - the organization that administers the SAT - I am a part of a team that tracks statewide participation and recommends where money is best spent to improve SAT participation rates. Since the introduction of the new format, levels of participation in the various states have changed with regards to the various legislative decisions.*
#
# *This project is tasked with the exploration of the trends in SAT and ACT participation rates for the years 2017 to 2019, and seek to identify any trends that will help in the recommendations to the College Board on how to improve the participation rates in states with low or decreasing SAT participation rates.*

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from students' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# In 2016, the College Board made format, content and scoring changes to the SAT.
#
# With this in mind, the scoring sections are changed from the old format of three sections of Critical Reading, Writing and Math to the updated two sections of Evidence-Based Writing and Reading, and Math. The Essay portion of the SAT which was once part of the Writing section is now completely optional. With these two sections, the structure of the test is also adjusted to fit with the criteria.
#
# The total scoring is then adjusted from the 600-2400 range to the new 400-1600 range. Another change is with regards to the guessing penalty, which was removed instead of the original $ \frac{1}{4} $.

# %% [markdown]
# ### Choose your Data
#
# There are 6 datasets utilized that are included in the [`data`](./data/) folder for this project.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **Outside Research listed:**
# - Rado, D. (2016, February 11) *Illinois moves ahead with new testing plan, replacing ACT with SAT.* Retrieved from https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html
# - Gorski, E. (2015, December 12) *Goodbye ACT, hello SAT: a significant change for Colorado high schoolers.* Retrieved from https://co.chalkbeat.org/2015/12/23/21092477/goodbye-act-hello-sat-a-significant-change-for-colorado-high-schoolers
# - Colorado's Children Campaign (2016, January) *Colorado’s Switch from ACT to SAT.* Retrieved from https://www.coloradokids.org/wp-content/uploads/2016/01/ACTvsSAT_FINAL.pdf
# - Quinn, R. (2017, September 13) *WV chooses SAT as new high school standardized test for juniors.* Retrieved from https://www.wvgazettemail.com/news/education/wv-chooses-sat-as-new-high-school-standardized-test-for-juniors/article_b60d2618-4943-56f6-b180-4b4442172ef8.html
# - Postal, L. (2019, September 24) *Florida’s SAT scores fall, following national trend as more take the test.* Retrieved from https://www.orlandosentinel.com/news/education/os-ne-sat-scores-florida-20190924-2ycpuogc2ndkrkwzdrkrjgrg64-story.html
# - Heimbach, A. (2021, July 15) *Which States Require the ACT? Full List and Advice.* Retrieved from https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def ave_num(numlist):
    """Returns the mean of the list of numbers"""
    return sum(numlist)/len(numlist)

# %%
# testing the ave_num function on sample list of numbers
numlist = [1, 5, 6, 7, 8, 9, 0, 6]
ave_num(numlist)
# Out:
# 5.25

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
def std_dev(numlist):
    deviations = [(i - ave_num(numlist)) ** 2 for i in numlist]
    variance = sum(deviations)/len(numlist)
    return variance ** 0.5

# %%
#testing the std_dev function on the sample list of numbers
std_dev(numlist)
# Out:
# 2.9895651857753496

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
def data_clean(string_to_clean):
    clean_string = float(str(string_to_clean).replace("%",""))/100
    return clean_string

# %%
# testing the data_clean function on string
data_clean('50.5%')
# Out:
# 0.505

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:

# %%
sat_2017 = pd.read_csv('./data/sat_2017.csv')
sat_2018 = pd.read_csv('./data/sat_2018.csv')
sat_2019 = pd.read_csv('./data/sat_2019.csv')

act_2017 = pd.read_csv('./data/act_2017.csv')
act_2018 = pd.read_csv('./data/act_2018.csv')
act_2019 = pd.read_csv('./data/act_2019.csv')

# %% [markdown]
# **1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.**

# %%
# displaying the first 5 rows of the three SAT dataframes
display(sat_2017.head())
display(sat_2018.head())
display(sat_2019.head())
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076
# ...

# %%
# displaying the first 5 rows of the three ACT dataframes
display(act_2017.head())
display(act_2018.head())
display(act_2019.head())
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
#         State Participation  Composite
# 0     Alabama          100%       18.9
# 1      Alaska           38%       20.1
# 2     Arizona           73%       19.0
# 3    Arkansas          100%       19.3
# 4  California           23%       22.6

# %%
# displaying the last 5 rows of the three SAT dataframes
display(sat_2017.tail())
display(sat_2018.tail())
display(sat_2019.tail())
# Out:
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 46       Virginia           65%                                 561   541
# 47     Washington           64%                                 541   534
# 48  West Virginia           14%                                 558   528
# 49      Wisconsin            3%                                 642   649
# 50        Wyoming            3%                                 626   604
#
#     Total
# 46   1102
# 47   1075
# 48   1086
# 49   1291
# 50   1230
#             State Participation  Evidence-Based Reading and Writing  Math  \
# 46       Virginia           68%                                 567   550
# 47     Washington           69%                                 543   538
# 48  West Virginia           28%                                 513   486
# 49      Wisconsin            3%                                 641   653
# 50        Wyoming            3%                                 633   625
#
# ...

# %%
# displaying the last 5 rows of the three SAT dataframes
display(act_2017.tail())
display(act_2018.tail())
display(act_2019.tail())
# Out:
#             State Participation  English  Math  Reading  Science Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5      23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0      21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5      20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9      20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6     20.2x
#             State Participation  Composite
# 47       Virginia           24%       23.9
# 48     Washington           24%       22.2
# 49  West Virginia           65%       20.3
# 50      Wisconsin          100%       20.5
# 51        Wyoming          100%       20.0
#             State Participation  Composite
# 47     Washington           24%       22.1
# 48  West Virginia           49%       20.8
# 49      Wisconsin          100%       20.3
# 50        Wyoming          100%       19.8
# ...

# %% [markdown]
# **2. Check for missing values.**

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %%
act_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   Composite      52 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.3+ KB

# %% [markdown]
# **Observations**
# - From the .info above, there does not seem to be any missing values in all 6 dataframes.
# - But it should be noted that with regards to the SAT, SAT 2019 has two more rows of data.
# - It should also be noted that ACT 2017 has 4 more columns besides States, Participation and Composite.
# - Also, the Composite column for ACT 2017 is recorded as object instead of float64. Looking at the .tail() of ACT 2017 shows that there is an error in the entry for Wyoming.
# - Comparing the number of rows for the ACT and SAT, it should be noted SAT has 51 rows while ACT has 52 rows, but it can be noted from the .head() and .tail() that ACT 2017 has the first row for 'National' and ACT 2019 has the last row for 'National'. This indicates ACT 2019 is likely to have a duplicate row or a row with errors.

# %%
# checking for the additional rows in SAT 2019
sat_2017_statelist = list(sat_2017['State'])
sat_2018_statelist = list(sat_2018['State'])
sat_2019_statelist = list(sat_2019['State'])

for i in sat_2019_statelist:
    if i not in sat_2017_statelist:
        print(f'{i} not in SAT 2017 State.')
    if i not in sat_2018_statelist:
        print(f'{i} not in SAT 2018 State.')
# Out:
# Puerto Rico not in SAT 2017 State.
# Puerto Rico not in SAT 2018 State.
# Virgin Islands not in SAT 2017 State.
# Virgin Islands not in SAT 2018 State.

# %%
display(sat_2019[sat_2019['State'] == 'Puerto Rico'])
display(sat_2019[sat_2019['State'] == 'Virgin Islands'])
# Out:
#           State Participation Rate  EBRW  Math  Total
# 39  Puerto Rico                  —   483   462    944
#              State Participation Rate  EBRW  Math  Total
# 47  Virgin Islands                  —   490   445    935

# %% [markdown]
# - Seeing that the two States 'Puerto Rico' and 'Virgin Islands' are newly added to SAT 2019, as well as a missing value for their Participation Rate, it would be better to drop these two rows.

# %%
# Checking for the row for 'National' in the three ACT dataframes
display(act_2017[act_2017['State'] == 'National'])
display(act_2018[act_2018['State'] == 'National'])
display(act_2019[act_2019['State'] == 'National'])
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# Empty DataFrame
# Columns: [State, Participation, Composite]
# Index: []
#        State Participation  Composite
# 51  National           52%       20.7

# %%
# checking for duplicate states in the three ACT dataframes
display(act_2017[act_2017.duplicated(subset='State', keep='last')])
display(act_2018[act_2018.duplicated(subset='State', keep='last')])
display(act_2019[act_2019.duplicated(subset='State', keep='last')])
# Out:
# Empty DataFrame
# Columns: [State, Participation, English, Math, Reading, Science, Composite]
# Index: []
#     State Participation  Composite
# 19  Maine            7%       24.0
# Empty DataFrame
# Columns: [State, Participation, Composite]
# Index: []

# %% [markdown]
# - This duplicate row for 'Maine' in ACT 2018 will need to be dropped later.

# %%
act_2017_statelist = list(act_2017['State']) 
act_2018_statelist = list(act_2018['State'])
act_2019_statelist = list(act_2019['State'])

# Checking for missing states in the three SAT dataframes
for i in act_2017_statelist:
    if i not in act_2018_statelist:
        print(f'{i} not in ACT 2018 State.')
    if i not in act_2019_statelist:
        print(f'{i} not in ACT 2019 State.')

print()
for j in act_2018_statelist:
    if j not in act_2017_statelist:
        print(f'{j} not in ACT 2017 State.')
    if j not in act_2019_statelist:
        print(f'{j} not in ACT 2019 State.')
       
print()
for k in act_2019_statelist:
    if k not in act_2017_statelist:
        print(f'{k} not in ACT 2017 State.')
    if k not in act_2018_statelist:
        print(f'{k} not in ACT 2018 State.')
# Out:
# National not in ACT 2018 State.
# District of Columbia not in ACT 2018 State.
#
# District of columbia not in ACT 2017 State.
# District of columbia not in ACT 2019 State.
#
# District of Columbia not in ACT 2018 State.
# National not in ACT 2018 State.

# %% [markdown]
# - Note the missing 'National' in ACT 2018 and the error in the spelling of 'District of Columbia'

# %%
display(act_2017[act_2017['State'] == 'District of Columbia'])
display(act_2018[act_2018['State'] == 'District of columbia'])
display(act_2019[act_2019['State'] == 'District of Columbia'])
# Out:
#                   State Participation  English  Math  Reading  Science  \
# 9  District of Columbia           32%     24.4  23.5     24.9     23.5
#
#   Composite
# 9      24.2
#                   State Participation  Composite
# 8  District of columbia           32%       23.6
#                   State Participation  Composite
# 8  District of Columbia           32%       23.5

# %% [markdown]
# **Summary**
# - From above, there does not seem to be any missing values in the dataframes.
# - With regards to the SAT dataframes, SAT 2019 has two more rows 'Puerto Rico' and 'Virgin Islands', which has no listed Participation Rate. I suggest to drop these two rows.
# - With regards to the ACT dataframes, ACT 2017 has 4 more columns besides States, Participation and Composite, but this is insignificant since I am looking at the Participation Rates of the dataframes.
# - Also, the Composite column for ACT 2017 is recorded as object instead of float64. Looking at the .tail() of ACT 2017 shows that there is an error in the entry for Wyoming, which has to be corrected.
# - Comparing the number of rows for the ACT and SAT dataframes, it should be noted SAT has 51 rows while ACT has 52 rows, but it can be noted from the .head() and .tail() that ACT 2017 has the first row for 'National' and ACT 2019 has the last row for 'National'. There is also an additonal duplicate row for 'Maine' in ACT 2018.
# - By dropping those rows, the final result will have 51 rows for both the SAT and ACT dataframes.
# - Finally, in ACT 2018, there is a misspelling for the 'District of Columbia' as 'District of columbia' which will have to be corrected.

# %% [markdown]
# **3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).**

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# - SAT 2017 has a min Math score of 52, which is far more than 3 standard deviations away from the mean, indicating there is likely to be an error.

# %%
sat_2017.sort_values(['Math']).head()
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 20              Maryland           69%                                 536
# 8   District of Columbia          100%                                 482
# 7               Delaware          100%                                 503
# 12                 Idaho           93%                                 513
# 22              Michigan          100%                                 509
#
#     Math  Total
# 20    52   1060
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005

# %%
sat_2018.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           563.686275  556.235294  1120.019608
# std                             47.502627   47.772623    94.155083
# min                            480.000000  480.000000   977.000000
# 25%                            534.500000  522.500000  1057.500000
# 50%                            552.000000  544.000000  1098.000000
# 75%                            610.500000  593.500000  1204.000000
# max                            643.000000  655.000000  1298.000000

# %%
sat_2019.describe()
# Out:
#              EBRW        Math        Total
# count   53.000000   53.000000    53.000000
# mean   558.000000  548.471698  1106.528302
# std     47.554422   53.785044   100.994784
# min    483.000000  445.000000   935.000000
# 25%    518.000000  506.000000  1024.000000
# 50%    550.000000  545.000000  1097.000000
# 75%    610.000000  596.000000  1200.000000
# max    636.000000  648.000000  1284.000000

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %% [markdown]
# - ACT 2017 has a min Science score of 2.3, which is far off from the other values, indicating an error.
# - Composite is not showing up since there is an error in the entries which result in being displayed as object.

# %%
act_2017.sort_values(['Science']).head()
# Out:
#              State Participation  English  Math  Reading  Science Composite
# 21        Maryland           28%     23.3  23.1     24.2      2.3      23.6
# 29          Nevada          100%     16.3  18.0     18.1     18.2      17.8
# 25     Mississippi          100%     18.2  18.1     18.8     18.8      18.6
# 41  South Carolina          100%     17.5  18.6     19.1     18.9      18.7
# 34  North Carolina          100%     17.8  19.3     19.6     19.3      19.1

# %%
act_2018.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.544231
# std     2.119417
# min    17.700000
# 25%    19.975000
# 50%    21.300000
# 75%    23.725000
# max    25.600000

# %%
act_2019.describe()
# Out:
#        Composite
# count  52.000000
# mean   21.450000
# std     2.175487
# min    17.900000
# 25%    19.800000
# 50%    20.950000
# 75%    23.650000
# max    25.500000

# %% [markdown]
# **4. Fix any errors you identified in steps 2-3.**

# %%
# Correcting the minimum score in Math for SAT 2017
# from https://reports.collegeboard.org/pdf/2017-maryland-sat-suite-assessments-annual-report.pdf-0

sat_2017['Math'].replace(52, 524, inplace=True)

# %%
sat_2017.sort_values(['Math']).head()
# Out:
#                    State Participation  Evidence-Based Reading and Writing  \
# 8   District of Columbia          100%                                 482
# 7               Delaware          100%                                 503
# 12                 Idaho           93%                                 513
# 22              Michigan          100%                                 509
# 9                Florida           83%                                 520
#
#     Math  Total
# 8    468    950
# 7    492    996
# 12   493   1005
# 22   495   1005
# 9    497   1017

# %%
# Showing the rows for the States of Puerto Rico and Virgin Islands in SAT 2019 
display(sat_2019.iloc[38:41]) 
display(sat_2019.iloc[46:49])
# Out:
#            State Participation Rate  EBRW  Math  Total
# 38  Pennsylvania                70%   545   537   1082
# 39   Puerto Rico                  —   483   462    944
# 40  Rhode Island               100%   503   492    995
#              State Participation Rate  EBRW  Math  Total
# 46         Vermont                66%   560   546   1106
# 47  Virgin Islands                  —   490   445    935
# 48        Virginia                68%   567   551   1119

# %%
# Dropping the rows for the States of Puerto Rico and Virgin Islands in SAT 2019
sat_2019.drop([39,47], inplace=True)

# %%
display(sat_2019.iloc[38:41])
display(sat_2019.iloc[45:49])
# Out:
#              State Participation Rate  EBRW  Math  Total
# 38    Pennsylvania                70%   545   537   1082
# 40    Rhode Island               100%   503   492    995
# 41  South Carolina                68%   526   504   1030
#             State Participation Rate  EBRW  Math  Total
# 46        Vermont                66%   560   546   1106
# 48       Virginia                68%   567   551   1119
# 49     Washington                70%   539   535   1074
# 50  West Virginia                99%   483   460    943

# %%
# fixing the error in Wyoming in 2017 with the additional x.

act_2017['Composite'] = act_2017['Composite'].apply(lambda x : float(x.replace("x","")))
act_2017.tail()
# Out:
#             State Participation  English  Math  Reading  Science  Composite
# 47       Virginia           29%     23.5  23.3     24.6     23.5       23.8
# 48     Washington           29%     20.9  21.9     22.1     22.0       21.9
# 49  West Virginia           69%     20.0  19.4     21.2     20.5       20.4
# 50      Wisconsin          100%     19.7  20.4     20.6     20.9       20.5
# 51        Wyoming          100%     19.4  19.8     20.8     20.6       20.2

# %%
# Correcting the minimum score in Science for ACT 2017
# replace incorrect data with source data from https://www.act.org/content/dam/act/unsecured/documents/cccr2017/ACT_2017-Average_Scores_by_State.pdf

act_2017['Science'].replace(2.3, 23.2, inplace=True)

# %%
act_2017.sort_values(['Science']).head()
# Out:
#              State Participation  English  Math  Reading  Science  Composite
# 29          Nevada          100%     16.3  18.0     18.1     18.2       17.8
# 25     Mississippi          100%     18.2  18.1     18.8     18.8       18.6
# 41  South Carolina          100%     17.5  18.6     19.1     18.9       18.7
# 34  North Carolina          100%     17.8  19.3     19.6     19.3       19.1
# 12          Hawaii           90%     17.8  19.2     19.2     19.3       19.0

# %%
# dropping the dupe row 'Maine' for ACT 2018

act_2018.drop(19, inplace=True)
display(act_2018[act_2018['State'] == 'Maine'])
# Out:
#     State Participation  Composite
# 20  Maine            7%       24.0

# %%
# correcting the name for District of Columbia for Act 2018

act_2018['State'].replace('District of columbia', 'District of Columbia', inplace=True)
display(act_2018[act_2018['State'] == 'District of Columbia'])
# Out:
#                   State Participation  Composite
# 8  District of Columbia           32%       23.6

# %%
# Dropping the rows for the state "National" in 2017 and 2019 since this is the average

act_2017.drop(0, inplace=True)
act_2019.drop(51, inplace=True)

display(act_2017.head())
display(act_2019.tail())
# Out:
#         State Participation  English  Math  Reading  Science  Composite
# 1     Alabama          100%     18.9  18.4     19.7     19.4       19.2
# 2      Alaska           65%     18.7  19.8     20.4     19.9       19.8
# 3     Arizona           62%     18.6  19.8     20.1     19.8       19.7
# 4    Arkansas          100%     18.9  19.0     19.7     19.5       19.4
# 5  California           31%     22.5  22.7     23.1     22.2       22.8
#             State Participation  Composite
# 46       Virginia           21%       24.0
# 47     Washington           24%       22.1
# 48  West Virginia           49%       20.8
# 49      Wisconsin          100%       20.3
# 50        Wyoming          100%       19.8

# %% [markdown]
# **5. Display the data types of each feature.**

# %%
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_2018.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %%
sat_2019.dtypes
# Out:
# State                 object
# Participation Rate    object
# EBRW                   int64
# Math                   int64
# Total                  int64
# dtype: object

# %%
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %%
act_2018.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %%
act_2019.dtypes
# Out:
# State             object
# Participation     object
# Composite        float64
# dtype: object

# %% [markdown]
# **6. Fix any incorrect data types found in step 5.**
#    - Fix any individual values preventing other columns from being the appropriate type.
#    - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.

# %%
# Fixing the Participation Rate for the States of Puerto Rico and Virgin Islands written as -

sat_2019['Participation Rate'].replace( '—' , '0%' , inplace=True)

# %%
sat_2017['Participation'] = sat_2017['Participation'].apply(data_clean)
sat_2017.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.05                                 593   572   1165
# 1      Alaska           0.38                                 547   533   1080
# 2     Arizona           0.30                                 563   553   1116
# 3    Arkansas           0.03                                 614   594   1208
# 4  California           0.53                                 531   524   1055

# %%
sat_2018['Participation'] = sat_2018['Participation'].apply(data_clean)
sat_2018.head()
# Out:
#         State  Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama           0.06                                 595   571   1166
# 1      Alaska           0.43                                 562   544   1106
# 2     Arizona           0.29                                 577   572   1149
# 3    Arkansas           0.05                                 592   576   1169
# 4  California           0.60                                 540   536   1076

# %%
sat_2019['Participation Rate'] = sat_2019['Participation Rate'].apply(data_clean)
sat_2019.head()
# Out:
#         State  Participation Rate  EBRW  Math  Total
# 0     Alabama                0.07   583   560   1143
# 1      Alaska                0.41   556   541   1097
# 2     Arizona                0.31   569   565   1134
# 3    Arkansas                0.06   582   559   1141
# 4  California                0.63   534   531   1065

# %%
act_2017['Participation'] = act_2017['Participation'].apply(data_clean)
act_2017.head()
# Out:
#         State  Participation  English  Math  Reading  Science  Composite
# 1     Alabama           1.00     18.9  18.4     19.7     19.4       19.2
# 2      Alaska           0.65     18.7  19.8     20.4     19.9       19.8
# 3     Arizona           0.62     18.6  19.8     20.1     19.8       19.7
# 4    Arkansas           1.00     18.9  19.0     19.7     19.5       19.4
# 5  California           0.31     22.5  22.7     23.1     22.2       22.8

# %%
act_2018['Participation'] = act_2018['Participation'].apply(data_clean)
act_2018.head()
# Out:
#         State  Participation  Composite
# 0     Alabama           1.00       19.1
# 1      Alaska           0.33       20.8
# 2     Arizona           0.66       19.2
# 3    Arkansas           1.00       19.4
# 4  California           0.27       22.7

# %%
act_2019['Participation'] = act_2019['Participation'].apply(data_clean)
act_2019.head()
# Out:
#         State  Participation  Composite
# 0     Alabama           1.00       18.9
# 1      Alaska           0.38       20.1
# 2     Arizona           0.73       19.0
# 3    Arkansas           1.00       19.3
# 4  California           0.23       22.6

# %% [markdown]
# **7. Rename Columns.**
#    - Column names should be all lowercase.
#    - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#    - Column names should be unique and informative.

# %%
sat_2017.columns = ['state', 'sat_part_17', 'sat_edrw_17', 'sat_math_17', 'sat_total_17']
sat_2017.head()
# Out:
#         state  sat_part_17  sat_edrw_17  sat_math_17  sat_total_17
# 0     Alabama         0.05          593          572          1165
# 1      Alaska         0.38          547          533          1080
# 2     Arizona         0.30          563          553          1116
# 3    Arkansas         0.03          614          594          1208
# 4  California         0.53          531          524          1055

# %%
sat_2018.columns = ['state', 'sat_part_18', 'sat_edrw_18', 'sat_math_18', 'sat_total_18']
sat_2018.head()
# Out:
#         state  sat_part_18  sat_edrw_18  sat_math_18  sat_total_18
# 0     Alabama         0.06          595          571          1166
# 1      Alaska         0.43          562          544          1106
# 2     Arizona         0.29          577          572          1149
# 3    Arkansas         0.05          592          576          1169
# 4  California         0.60          540          536          1076

# %%
sat_2019.columns = ['state', 'sat_part_19', 'sat_edrw_19', 'sat_math_19', 'sat_total_19']
sat_2019.head()
# Out:
#         state  sat_part_19  sat_edrw_19  sat_math_19  sat_total_19
# 0     Alabama         0.07          583          560          1143
# 1      Alaska         0.41          556          541          1097
# 2     Arizona         0.31          569          565          1134
# 3    Arkansas         0.06          582          559          1141
# 4  California         0.63          534          531          1065

# %%
act_2017.columns = ['state', 'act_part_17', 'act_eng_17', 'act_math_17', 'act_read_17', 'act_sci_17', 'act_comp_17']
act_2017.head()
# Out:
#         state  act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  \
# 1     Alabama         1.00        18.9         18.4         19.7        19.4
# 2      Alaska         0.65        18.7         19.8         20.4        19.9
# 3     Arizona         0.62        18.6         19.8         20.1        19.8
# 4    Arkansas         1.00        18.9         19.0         19.7        19.5
# 5  California         0.31        22.5         22.7         23.1        22.2
#
#    act_comp_17
# 1         19.2
# 2         19.8
# 3         19.7
# 4         19.4
# 5         22.8

# %%
act_2018.columns = ['state', 'act_part_18', 'act_comp_18']
act_2018.head()
# Out:
#         state  act_part_18  act_comp_18
# 0     Alabama         1.00         19.1
# 1      Alaska         0.33         20.8
# 2     Arizona         0.66         19.2
# 3    Arkansas         1.00         19.4
# 4  California         0.27         22.7

# %%
act_2019.columns = ['state', 'act_part_19', 'act_comp_19']
act_2019.head()
# Out:
#         state  act_part_19  act_comp_19
# 0     Alabama         1.00         18.9
# 1      Alaska         0.38         20.1
# 2     Arizona         0.73         19.0
# 3    Arkansas         1.00         19.3
# 4  California         0.23         22.6

# %% [markdown]
# **8. Drop unnecessary rows (if needed).**

# %%
# Since the unnecessary rows has already been dropped in step 4, 
# there should be no further rows that need to be dropped for the merging of dataframes

# %% [markdown]
# **9. Merge dataframes that can be merged.**

# %%
sat_2017_2018 = pd.merge(sat_2017, sat_2018, how ='left')
sat_2017_2018.head()
# Out:
#         state  sat_part_17  sat_edrw_17  sat_math_17  sat_total_17  \
# 0     Alabama         0.05          593          572          1165
# 1      Alaska         0.38          547          533          1080
# 2     Arizona         0.30          563          553          1116
# 3    Arkansas         0.03          614          594          1208
# 4  California         0.53          531          524          1055
#
#    sat_part_18  sat_edrw_18  sat_math_18  sat_total_18
# 0         0.06          595          571          1166
# 1         0.43          562          544          1106
# 2         0.29          577          572          1149
# 3         0.05          592          576          1169
# 4         0.60          540          536          1076

# %%
combined_sat = pd.merge(sat_2017_2018, sat_2019, how ='left')
combined_sat.head()
# Out:
#         state  sat_part_17  sat_edrw_17  sat_math_17  sat_total_17  \
# 0     Alabama         0.05          593          572          1165
# 1      Alaska         0.38          547          533          1080
# 2     Arizona         0.30          563          553          1116
# 3    Arkansas         0.03          614          594          1208
# 4  California         0.53          531          524          1055
#
#    sat_part_18  sat_edrw_18  sat_math_18  sat_total_18  sat_part_19  \
# 0         0.06          595          571          1166         0.07
# 1         0.43          562          544          1106         0.41
# 2         0.29          577          572          1149         0.31
# 3         0.05          592          576          1169         0.06
# 4         0.60          540          536          1076         0.63
#
#    sat_edrw_19  sat_math_19  sat_total_19
# 0          583          560          1143
# 1          556          541          1097
# ...

# %%
act_2017_2018 = pd.merge(act_2017, act_2018, how='left')
act_2017_2018.head()
# Out:
#         state  act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  \
# 0     Alabama         1.00        18.9         18.4         19.7        19.4
# 1      Alaska         0.65        18.7         19.8         20.4        19.9
# 2     Arizona         0.62        18.6         19.8         20.1        19.8
# 3    Arkansas         1.00        18.9         19.0         19.7        19.5
# 4  California         0.31        22.5         22.7         23.1        22.2
#
#    act_comp_17  act_part_18  act_comp_18
# 0         19.2         1.00         19.1
# 1         19.8         0.33         20.8
# 2         19.7         0.66         19.2
# 3         19.4         1.00         19.4
# 4         22.8         0.27         22.7

# %%
combined_act = pd.merge(act_2017_2018, act_2019, how='left')
combined_act.head()
# Out:
#         state  act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  \
# 0     Alabama         1.00        18.9         18.4         19.7        19.4
# 1      Alaska         0.65        18.7         19.8         20.4        19.9
# 2     Arizona         0.62        18.6         19.8         20.1        19.8
# 3    Arkansas         1.00        18.9         19.0         19.7        19.5
# 4  California         0.31        22.5         22.7         23.1        22.2
#
#    act_comp_17  act_part_18  act_comp_18  act_part_19  act_comp_19
# 0         19.2         1.00         19.1         1.00         18.9
# 1         19.8         0.33         20.8         0.38         20.1
# 2         19.7         0.66         19.2         0.73         19.0
# 3         19.4         1.00         19.4         1.00         19.3
# 4         22.8         0.27         22.7         0.23         22.6

# %%
combined_total = pd.merge(combined_sat, combined_act, how='left')
combined_total.head()
# Out:
#         state  sat_part_17  sat_edrw_17  sat_math_17  sat_total_17  \
# 0     Alabama         0.05          593          572          1165
# 1      Alaska         0.38          547          533          1080
# 2     Arizona         0.30          563          553          1116
# 3    Arkansas         0.03          614          594          1208
# 4  California         0.53          531          524          1055
#
#    sat_part_18  sat_edrw_18  sat_math_18  sat_total_18  sat_part_19  ...  \
# 0         0.06          595          571          1166         0.07  ...
# 1         0.43          562          544          1106         0.41  ...
# 2         0.29          577          572          1149         0.31  ...
# 3         0.05          592          576          1169         0.06  ...
# 4         0.60          540          536          1076         0.63  ...
#
#    act_part_17  act_eng_17  act_math_17  act_read_17  act_sci_17  act_comp_17  \
# ...

# %% [markdown]
# **10. Perform any additional cleaning that you feel is necessary.**

# %%
# Is there any additional cleaning needed? To check again.
combined_total.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   state         51 non-null     object
#  1   sat_part_17   51 non-null     float64
#  2   sat_edrw_17   51 non-null     int64
#  3   sat_math_17   51 non-null     int64
#  4   sat_total_17  51 non-null     int64
#  5   sat_part_18   51 non-null     float64
#  6   sat_edrw_18   51 non-null     int64
#  7   sat_math_18   51 non-null     int64
#  8   sat_total_18  51 non-null     int64
#  9   sat_part_19   51 non-null     float64
#  10  sat_edrw_19   51 non-null     int64
#  11  sat_math_19   51 non-null     int64
#  12  sat_total_19  51 non-null     int64
#  13  act_part_17   51 non-null     float64
#  14  act_eng_17    51 non-null     float64
#  15  act_math_17   51 non-null     float64
#  16  act_read_17   51 non-null     float64
#  17  act_sci_17    51 non-null     float64
# ...

# %%
# Since we are mostly going to look at the Participation Rates, 
# it would be better to drop all the scores except for the Total and Composite to make the data neater.
columns_to_drop = ['sat_edrw_17','sat_math_17','sat_edrw_18','sat_math_18','sat_edrw_19','sat_math_19','act_eng_17','act_math_17','act_read_17','act_sci_17']
combined_total.drop(columns = columns_to_drop, inplace=True)
combined_total.head()
# Out:
#         state  sat_part_17  sat_total_17  sat_part_18  sat_total_18  \
# 0     Alabama         0.05          1165         0.06          1166
# 1      Alaska         0.38          1080         0.43          1106
# 2     Arizona         0.30          1116         0.29          1149
# 3    Arkansas         0.03          1208         0.05          1169
# 4  California         0.53          1055         0.60          1076
#
#    sat_part_19  sat_total_19  act_part_17  act_comp_17  act_part_18  \
# 0         0.07          1143         1.00         19.2         1.00
# 1         0.41          1097         0.65         19.8         0.33
# 2         0.31          1134         0.62         19.7         0.66
# 3         0.06          1141         1.00         19.4         1.00
# 4         0.63          1065         0.31         22.8         0.27
#
#    act_comp_18  act_part_19  act_comp_19
# 0         19.1         1.00         18.9
# 1         20.8         0.38         20.1
# ...

# %% [markdown]
# **11. Save your cleaned and merged dataframes as csv files.**

# %%
combined_total.to_csv('./data/combined_total.csv')

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**state**|*object*|SAT 2017|The States of the country participating in SAT and ACT|
# |**sat_part_17**|*float*|SAT 2017|The Participation Rate of students for the State for SAT 2017 (units percent to two decimal places, 0.02 means 2%)|
# |**sat_total_17**|*integer*|SAT 2017|The total mean score for the State for SAT 2017 (out of the possible score from 400 to 1,600)|
# |**sat_part_18**|*float*|SAT 2018|The Participation Rate of students for the State for SAT 2018 (units percent to two decimal places, 0.02 means 2%)|
# |**sat_total_18**|*integer*|SAT 2018|The total mean score for the State for SAT 2018 (out of the possible score from 400 to 1,600)|
# |**sat_part_19**|*float*|SAT 2019|The Participation Rate of students for the State for SAT 2019 (units percent to two decimal places, 0.02 means 2%)|
# |**sat_total_19**|*integer*|SAT 2019|The total mean score for the State for SAT 2019 (out of the possible score from 400 to 1,600)|
# |**act_part_17**|*float*|ACT 2017|The Participation Rate of students for the State for ACT 2017 (units percent to two decimal places, 0.02 means 2%)|
# |**act_comp_17**|*float*|ACT 2017|The total composite score for the State for ACT 2017 (out of the possible score from 1 to 36)|
# |**act_part_18**|*float*|ACT 2017|The Participation Rate of students for the State for ACT 2018 (units percent to two decimal places, 0.02 means 2%)|
# |**act_comp_18**|*float*|ACT 2017|The total composite score for the State for ACT 2018 (out of the possible score from 1 to 36)|
# |**act_part_19**|*float*|ACT 2017|The Participation Rate of students for the State for ACT 2019 (units percent to two decimal places, 0.02 means 2%)|
# |**act_comp_19**|*float*|ACT 2017|The total composite score for the State for ACT 2019 (out of the possible score from 1 to 36)|

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.

# %%
combined_total.describe().T
# Out:
#               count         mean        std     min       25%      50%  \
# sat_part_17    51.0     0.398039   0.352766    0.02     0.040     0.38
# sat_total_17   51.0  1126.098039  92.494812  950.00  1055.500  1107.00
# sat_part_18    51.0     0.457451   0.373143    0.02     0.045     0.52
# sat_total_18   51.0  1120.019608  94.155083  977.00  1057.500  1098.00
# sat_part_19    51.0     0.490588   0.387476    0.02     0.055     0.54
# sat_total_19   51.0  1113.078431  97.197910  943.00  1038.000  1097.00
# act_part_17    51.0     0.652549   0.321408    0.08     0.310     0.69
# act_comp_17    51.0    21.519608   2.020695   17.80    19.800    21.40
# act_part_18    51.0     0.617255   0.340371    0.07     0.285     0.66
# act_comp_18    51.0    21.496078   2.111583   17.70    19.950    21.30
# act_part_19    51.0     0.586667   0.345159    0.06     0.245     0.54
# act_comp_19    51.0    21.464706   2.194523   17.90    19.800    21.10
#
#                    75%     max
# ...

# %% [markdown]
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
sd = {n: round(std_dev(combined_total[n]), 6) for n in combined_total.columns[1:]}
sd # note how the standard deviation differs from the ones in the describe.() above
# Out:
# {'sat_part_17': 0.349291,
#  'sat_total_17': 91.583511,
#  'sat_part_18': 0.369466,
#  'sat_total_18': 93.227424,
#  'sat_part_19': 0.383658,
#  'sat_total_19': 96.240272,
#  'act_part_17': 0.318242,
#  'act_comp_17': 2.000786,
#  'act_part_18': 0.337017,
#  'act_comp_18': 2.090779,
#  'act_part_19': 0.341758,
#  'act_comp_19': 2.172901}

# %%
# comparing the numpy standard deviation and the one from our function to see that they are the same

np.std(combined_total)
# Out:
# C:\Users\yongf\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3558: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# sat_part_17      0.349291
# sat_total_17    91.583511
# sat_part_18      0.369466
# sat_total_18    93.227424
# sat_part_19      0.383658
# sat_total_19    96.240272
# act_part_17      0.318242
# act_comp_17      2.000786
# act_part_18      0.337017
# act_comp_18      2.090779
# act_part_19      0.341758
# act_comp_19      2.172901
# dtype: float64

# %% [markdown]
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2018, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2018, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
combined_total[['state','sat_part_17']].sort_values('sat_part_17', ascending = False).head()
# Out:
#                    state  sat_part_17
# 8   District of Columbia         1.00
# 22              Michigan         1.00
# 6            Connecticut         1.00
# 7               Delaware         1.00
# 29         New Hampshire         0.96

# %% [markdown]
# The Highest Participation Rates for SAT 2017 are:
# - District of Columbia
# - Michigan
# - Connecticut
# - Delaware
# - New Hampshire

# %%
combined_total[['state','sat_part_17']].sort_values('sat_part_17').head()
# Out:
#            state  sat_part_17
# 34  North Dakota         0.02
# 24   Mississippi         0.02
# 15          Iowa         0.02
# 25      Missouri         0.03
# 44          Utah         0.03

# %% [markdown]
# The Lowest Participation Rates for SAT 2017 are:
# - North Dakota
# - Mississippi
# - Iowa
# - Missouri
# - Utah

# %%
combined_total[['state','sat_part_18']].sort_values('sat_part_18', ascending = False).head()
# Out:
#           state  sat_part_18
# 5      Colorado          1.0
# 6   Connecticut          1.0
# 7      Delaware          1.0
# 22     Michigan          1.0
# 12        Idaho          1.0

# %% [markdown]
# The Highest Participation Rates for SAT 2018 are:
# - Colorado
# - Connecticut
# - Delaware
# - Michigan
# - Idaho

# %%
combined_total[['state','sat_part_18']].sort_values('sat_part_18').head()
# Out:
#            state  sat_part_18
# 34  North Dakota         0.02
# 50       Wyoming         0.03
# 41  South Dakota         0.03
# 27      Nebraska         0.03
# 49     Wisconsin         0.03

# %% [markdown]
# The Lowest Participation Rates for SAT 2018 are:
# - North Dakota
# - Wyoming
# - South Dakota
# - Nebraska
# - Wisconsin

# %%
combined_total[combined_total['sat_part_19'] == 1][['state','sat_part_19']]
# Out:
#            state  sat_part_19
# 5       Colorado          1.0
# 6    Connecticut          1.0
# 7       Delaware          1.0
# 9        Florida          1.0
# 12         Idaho          1.0
# 13      Illinois          1.0
# 22      Michigan          1.0
# 39  Rhode Island          1.0

# %% [markdown]
# The Highest Participation Rates for SAT 2019 (with 100% Participation Rates) are:
# - Colorado
# - Connecticut
# - Delaware
# - Florida
# - Idaho
# - Illinois
# - Michigan
# - Rhode Island

# %%
combined_total[['state','sat_part_19']].sort_values('sat_part_19').head()
# Out:
#            state  sat_part_19
# 34  North Dakota         0.02
# 50       Wyoming         0.03
# 41  South Dakota         0.03
# 27      Nebraska         0.03
# 49     Wisconsin         0.03

# %% [markdown]
# The Lowest Participation Rates for SAT 2019 are:
# - North Dakota
# - Wyoming
# - South Dakota
# - Nebraska
# - Wisconsin

# %%
combined_total[combined_total['act_part_17'] == 1][['state','act_part_17']]
# Out:
#              state  act_part_17
# 0          Alabama          1.0
# 3         Arkansas          1.0
# 5         Colorado          1.0
# 17        Kentucky          1.0
# 18       Louisiana          1.0
# 23       Minnesota          1.0
# 24     Mississippi          1.0
# 25        Missouri          1.0
# 26         Montana          1.0
# 28          Nevada          1.0
# 33  North Carolina          1.0
# 36        Oklahoma          1.0
# 40  South Carolina          1.0
# 42       Tennessee          1.0
# 44            Utah          1.0
# 49       Wisconsin          1.0
# 50         Wyoming          1.0

# %% [markdown]
# The Highest Participation Rates for ACT 2017 (with 100% Participation Rates) are:
# - Alabama
# - Arkansas
# - Colorado
# - Kentucky
# - Louisiana
# - Minnesota
# - Mississippi
# - Missouri
# - Montana
# - Nevada
# - North Carolina
# - Oklahoma
# - South Carolina
# - Tennessee
# - Utah
# - Wisconsin
# - Wyoming

# %%
combined_total[['state','act_part_17']].sort_values('act_part_17').head()
# Out:
#             state  act_part_17
# 19          Maine         0.08
# 29  New Hampshire         0.18
# 7        Delaware         0.18
# 39   Rhode Island         0.21
# 38   Pennsylvania         0.23

# %% [markdown]
# The Lowest Participation Rates for ACT 2017 are:
# - Maine
# - New Hampshire
# - Delaware
# - Rhode Island
# - Pennsylvania

# %%
combined_total[combined_total['act_part_18'] == 1][['state','act_part_18']]
# Out:
#              state  act_part_18
# 0          Alabama          1.0
# 3         Arkansas          1.0
# 17        Kentucky          1.0
# 18       Louisiana          1.0
# 24     Mississippi          1.0
# 25        Missouri          1.0
# 26         Montana          1.0
# 27        Nebraska          1.0
# 28          Nevada          1.0
# 33  North Carolina          1.0
# 35            Ohio          1.0
# 36        Oklahoma          1.0
# 40  South Carolina          1.0
# 42       Tennessee          1.0
# 44            Utah          1.0
# 49       Wisconsin          1.0
# 50         Wyoming          1.0

# %% [markdown]
# The Highest Participation Rates for ACT 2018 (with 100% Participation Rates) are:
# - Alabama
# - Arkansas
# - Kentucky
# - Louisiana
# - Mississippi
# - Missouri
# - Montana
# - Nebraska
# - Nevada
# - North Carolina
# - Ohio
# - Oklahoma
# - South Carolina
# - Tennessee
# - Utah
# - Wisconsin
# - Wyoming

# %%
combined_total[['state','act_part_18']].sort_values('act_part_18').head()
# Out:
#             state  act_part_18
# 19          Maine         0.07
# 39   Rhode Island         0.15
# 29  New Hampshire         0.16
# 7        Delaware         0.17
# 38   Pennsylvania         0.20

# %% [markdown]
# The Lowest Participation Rates for ACT 2018 are:
# - Maine
# - Rhode Island
# - New Hampshire
# - Delaware
# - Pennsylvania

# %%
combined_total[combined_total['act_part_19'] == 1][['state','act_part_19']]
# Out:
#              state  act_part_19
# 0          Alabama          1.0
# 3         Arkansas          1.0
# 17        Kentucky          1.0
# 18       Louisiana          1.0
# 24     Mississippi          1.0
# 26         Montana          1.0
# 27        Nebraska          1.0
# 28          Nevada          1.0
# 33  North Carolina          1.0
# 35            Ohio          1.0
# 36        Oklahoma          1.0
# 42       Tennessee          1.0
# 44            Utah          1.0
# 49       Wisconsin          1.0
# 50         Wyoming          1.0

# %% [markdown]
# The Highest Participation Rates for ACT 2019 (with 100% Participation Rates) are:
# - Alabama
# - Arkansas
# - Kentucky
# - Louisiana
# - Mississippi
# - Montana
# - Nebraska
# - Nevada
# - North Carolina
# - Ohio
# - Oklahoma
# - Tennessee
# - Utah
# - Wisconsin
# - Wyoming

# %%
combined_total[['state','act_part_19']].sort_values('act_part_19').head()
# Out:
#             state  act_part_19
# 19          Maine         0.06
# 39   Rhode Island         0.12
# 7        Delaware         0.13
# 29  New Hampshire         0.14
# 38   Pennsylvania         0.17

# %% [markdown]
# The Lowest Participation Rates for ACT 2019 are:
# - Maine
# - Rhode Island
# - New Hampshire
# - Delaware
# - Pennsylvania

# %% [markdown]
# **Summary:**
#
# *A quick comparison with the highest and lowest participation rates of both the SAT and ACT over the three years show that the following observations:*
# - *A high participation rate of SAT will likely mean a low participation rate of ACT, and a high participation rate of ACT will likely mean a low participation rate SAT, and vice versa.*
# - *A high participation rate in a year will likely mean a high participation rate in the next year.*
# - *The opposite is also true: a low particpation rate in a year will also likely mean a low participation rate in the next year.*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---

# %% [markdown]
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
plt.figure(figsize = [16, 9]) # determining figure size of plot
corr = combined_total.corr()

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True # generating mask for heatmap

plt.title('SAT and ACT Correlations over the years 2017 to 2019', fontsize = 16) # setting title
colorsintheheatmap = sns.diverging_palette(20, 250, as_cmap=True) # generating color map

sns.heatmap(corr, cmap=colorsintheheatmap, mask = mask, annot = True); # heatmap with color map, mask and annotation

# %% [markdown]
# **Interpretation**
#
# *From the heatmap above, it can be easily be seen that:*
# - *For the same type of test, the Participation Rate is negatively correlated with the Score, meaning the higher the Participation Rate, the lower the Score becomes.*
# - *Also for the same type of test, the Scores are positively correlated and the Participation Rates are also positively correlated, meaning a high Score in one year will likely mean a high Score in another year, the same being with the Participation Rate.*
# - *However, for the two different types of tests, the Participation Rate of SAT is negatively correlated with the Participation Rate of ACT, meaning a high Participation Rate in SAT will likely give a low Participation Rate in ACT.
# - *The same is true for the Scores between the two types of tests, though it is much lesser.*
# - *As such, the correlations for the Participation Rates of one test and the Scores of the other test are positive due to the correlations mentioned before, though these are a lot weaker as they are not directly linked.*

# %% [markdown]
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
parts_list = ['sat_part_17', 'act_part_17', 'sat_part_18', 'act_part_18', 'sat_part_19', 'act_part_19']
titles_list = ['Participation Rate for SAT 2017', 'Participation Rate for ACT 2017', 'Participation Rate for SAT 2018',
              'Participation Rate for ACT 2018', 'Participation Rate for SAT 2019', 'Participation Rate for ACT 2019']

fig, ax = plt.subplots(3, 2, figsize = (20,20)) # determine number of subplots and figure size of plot
ax = ax.ravel() # turns into a flattened array for iteration.

for i, part in enumerate(parts_list):
    ax[i].hist(combined_total[part]) # histogram subplot of Participation Rate
    ax[i].vlines(x = np.median(combined_total[part]), ymin = 0, ymax = 20, color = 'brown', label = 'Median Line') # median line
    ax[i].set_title(titles_list[i]) # set title
    ax[i].axis([0, 1, 0, 22]) # set x-ais from 0 to 1, y-axis to 0 to 22
    ax[i].legend(loc = 'upper right', fontsize = 12) # set legend
    ax[i].set_xlabel('Participation Rate') # set label of x-axis
    ax[i].set_ylabel('Number of states'); # set label of y-axis

# %% [markdown]
# **Interpretation**
#
# *From the histograms above, we can see the histograms for ACT and SAT for the same year is roughly mirrored as the low distributions in the SAT correspond to the high distributions in the ACT. The same goes with the high distributions in the SAT roughly correspond to the low distributions in the ACT. This is likely due to the fact that most students will decide to only take one test. This observation can also be seen from the previous heat map due to the negative correlations indicating their inverse relations.*
#
# *However, it should also be noted that the histograms are only roughly mirrored as the near 100% participation rate in one does not mean a near 0% participation rate in the other. This is because there is likely to be students who take both tests in the same year, and as such, it will give out such a result.*
#
# *In the case of the SAT, we can easily see that median line for the Participation Rate has shifted to the right, meaning that the Participation Rate for the SAT has slowly increased over the years. This has also resulted in the larger number of states reaching 100% participation rate.*
#
# *Also, in the case of ACT, the opposite has happened as the median line for the Participation Rate has shifted to the low, meaning the Participation Rate has slowly decreased over the years.*

# %% [markdown]
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels

# %%
parts_list = ['sat_part_17', 'act_part_17', 'sat_part_18', 'act_part_18', 'sat_part_19', 'act_part_19']

plt.figure(figsize = [20, 10]) # determine figure size of plot

boxplot = sns.boxplot(data = combined_total[parts_list]) # plotting the boxplot of Participation Rate

plt.title('SAT and ACT Participation Rates over the years 2017 to 2019', fontsize = 16) # setting title
plt.ylabel('Participation Rate', fontsize = 16) # setting y-axis labels

# setting the x-axis tick labels
boxplot.set_xticklabels(['SAT 2017', 'ACT 2017', 'SAT 2018', 'ACT 2018', 'SAT 2019', 'ACT 2019'], fontsize = 16);

# %% [markdown]
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable

# %%
parts_list = ['sat_part_17', 'act_part_17', 'sat_part_18', 'act_part_18', 'sat_part_19', 'act_part_19']
scores_list = ['sat_total_17', 'act_comp_17', 'sat_total_18', 'act_comp_18', 'sat_total_19', 'act_comp_19']
titles_list = ['Participation Rate versus Total Mean Score for SAT 2017', 
               'Participation Rate versus Total Composite Score for ACT 2017', 
               'Participation Rate versus Total Mean Score for SAT 2018', 
               'Participation Rate versus Total Composite Score for ACT 2018', 
               'Participation Rate versus Total Mean Score for SAT 2019', 
               'Participation Rate versus Total Composite Score for ACT 2019']

fig, ax = plt.subplots(3, 2, figsize = (20,20)) # determine number of subplots and figure size of plot
ax = ax.ravel() # turns into a flattened array for iteration.

for i, column in enumerate(parts_list):
    ax[i].scatter(combined_total[column], combined_total[scores_list[i]]) # scatterplot of Participation Rate vs Score
    ax[i].plot([0,1],[1,0], transform=ax[i].transAxes, color='red', linestyle='dotted', label = 'Correlation') # showing the negative correlation
    ax[i].set_title(titles_list[i]) # set title
    ax[i].legend(loc = 'upper right', fontsize = 12) # set legend
    ax[i].set_xlabel('Participation Rate') # set label of x-axis
    ax[i].set_ylabel('Score'); # set label of y-axis

# %%
sat_list = ['sat_part_17', 'sat_part_18', 'sat_part_19']
act_list = ['act_part_17', 'act_part_18', 'act_part_19']
titles_list = ['SAT Participation Rate versus ACT Participation Rate for 2017', 
               'SAT Participation Rate versus ACT Participation Rate for 2018', 
               'SAT Participation Rate versus ACT Participation Rate for 2019']

fig, ax = plt.subplots(3, 1, figsize = (20,20)) # determine number of subplots and figure size of plot
ax = ax.ravel() # turns into a flattened array for iteration.

for i, column in enumerate(sat_list):
    ax[i].scatter(combined_total[column], combined_total[act_list[i]]) # scatterplot of Participation Rate vs Score
    ax[i].plot([0,1],[1,0], transform=ax[i].transAxes, color='red', linestyle='dotted', label = 'Correlation') # showing the negative correlation
    ax[i].set_title(titles_list[i]) # set title
    ax[i].legend(loc = 'upper right', fontsize = 12) # set legend
    ax[i].set_xlabel('SAT Participation Rate') # set label of x-axis
    ax[i].set_ylabel('ACT Participation Rate'); # set label of y-axis

# %% [markdown]
# **Interpretation**
#
# *From the scatter plots above, we can see the negative correlation between the Participation Rate and the Score, as denoted by the red line. For example, the states with higher Participation Rates having a lower Score and the states with lower Participation Rates having a higher Score*
#
# *Also, we can see the negative correlation between the Participation Rates of ACT and SAT, as denoted by the red line. For example, the states with higher Participation Rate in one having a lower Participation Rate in another. Of course, these does not apply very well to the states with 100% Participation Rates as some of them will not necessarily have very low Participation Rates.*

# %% [markdown]
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
# Looking at the difference in Participation Rates between the years for SAT and ACT
combined_total['sat_part_17_to_18'] = combined_total['sat_part_18'] - combined_total['sat_part_17']
combined_total['sat_part_18_to_19'] = combined_total['sat_part_19'] - combined_total['sat_part_18']
combined_total['act_part_17_to_18'] = combined_total['act_part_18'] - combined_total['act_part_17']
combined_total['act_part_18_to_19'] = combined_total['act_part_19'] - combined_total['act_part_18']
combined_total.head()
# Out:
#         state  sat_part_17  sat_total_17  sat_part_18  sat_total_18  \
# 0     Alabama         0.05          1165         0.06          1166
# 1      Alaska         0.38          1080         0.43          1106
# 2     Arizona         0.30          1116         0.29          1149
# 3    Arkansas         0.03          1208         0.05          1169
# 4  California         0.53          1055         0.60          1076
#
#    sat_part_19  sat_total_19  act_part_17  act_comp_17  act_part_18  \
# 0         0.07          1143         1.00         19.2         1.00
# 1         0.41          1097         0.65         19.8         0.33
# 2         0.31          1134         0.62         19.7         0.66
# 3         0.06          1141         1.00         19.4         1.00
# 4         0.63          1065         0.31         22.8         0.27
#
#    act_comp_18  act_part_19  act_comp_19  sat_part_17_to_18  \
# 0         19.1         1.00         18.9               0.01
# ...

# %%
combined_total.sort_values('sat_part_17_to_18').head() # Looking at the drop in Participation Rate in SAT from 2017 to 2018
# Out:
#                    state  sat_part_17  sat_total_17  sat_part_18  \
# 9                Florida         0.83          1017         0.56
# 8   District of Columbia         1.00           950         0.92
# 28                Nevada         0.26          1116         0.23
# 2                Arizona         0.30          1116         0.29
# 17              Kentucky         0.04          1247         0.04
#
#     sat_total_18  sat_part_19  sat_total_19  act_part_17  act_comp_17  \
# 9           1099         1.00           999         0.73         19.8
# 8            977         0.94           975         0.32         24.2
# 28          1140         0.20          1156         1.00         17.8
# 2           1149         0.31          1134         0.62         19.7
# 17          1248         0.04          1232         1.00         20.0
#
#     act_part_18  act_comp_18  act_part_19  act_comp_19  sat_part_17_to_18  \
# 9          0.66         19.9         0.54         20.1              -0.27
# ...

# %%
combined_total.sort_values('sat_part_18_to_19').head() # Looking at the drop in Participation Rate in SAT from 2018 to 2019
# Out:
#              state  sat_part_17  sat_total_17  sat_part_18  sat_total_18  \
# 28          Nevada         0.26          1116         0.23          1140
# 1           Alaska         0.38          1080         0.43          1106
# 11          Hawaii         0.55          1085         0.56          1010
# 26         Montana         0.10          1196         0.10          1198
# 33  North Carolina         0.49          1081         0.52          1098
#
#     sat_part_19  sat_total_19  act_part_17  act_comp_17  act_part_18  \
# 28         0.20          1156         1.00         17.8         1.00
# 1          0.41          1097         0.65         19.8         0.33
# 11         0.54          1100         0.90         19.0         0.89
# 26         0.09          1199         1.00         20.3         1.00
# 33         0.51          1100         1.00         19.1         1.00
#
#     act_comp_18  act_part_19  act_comp_19  sat_part_17_to_18  \
# ...

# %%
# Checking the new correlations 

plt.figure(figsize = [16, 9]) # determining figure size of plot
corr = combined_total.corr()

mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True # generating mask for heatmap

plt.title('SAT and ACT Correlations over the years 2017 to 2019', fontsize = 16) # setting title
colorsintheheatmap = sns.diverging_palette(20, 250, as_cmap=True) # generating color map

sns.heatmap(corr, cmap=colorsintheheatmap, mask = mask, annot = True); # heatmap with color map, mask and annotation

# %% [markdown]
# **Interpretation**
#
# *From the heatmap above, we can see there are some correlations between the Changes in Participation Rate and the Participation Rate of the tests of the later years, as well as the correlations with the Score of the tests of the later years.*
#
# *For example, the Change in Participation Rate in SAT from 2017 to 2018 is positively correlated to the Participation Rate of SAT in 2018 and 2019, and negatively correlated to the Participation Rate of ACT in 2018 and 2019.*
#
# *But this isn't useful at all.*
#
# *We will want to see if the Participation Rate of ACT or the Composite Score of ACT in the current year will affect the Change in Participation Rate in SAT from that year to the next to see how to identify the states that will need help.*

# %%
sat_act_list = ['act_part_17', 'act_part_18']
part_change_list = ['sat_part_17_to_18', 'sat_part_18_to_19']
titles_list = ['SAT Participation Rate Change from 2017 to 2018 versus ACT Participation Rate for 2017', 
               'SAT Participation Rate Change from 2018 to 2019 versus ACT Participation Rate for 2018']
xlabels_list = ['SAT Participation Rate Change from 2017 to 2018', 'SAT Participation Rate Change from 2018 to 2019']
ylabels_list = ['ACT Participation Rate for 2017', 'ACT Participation Rate for 2018']

# Plotting the scatter plot of the ACT Participation Rate versus the Change in SAT Participation Rate 
fig, ax = plt.subplots(2, 1, figsize = (16, 12)) # determine number of subplots and figure size of plot
ax = ax.ravel() # turns into a flattened array for iteration.

for i, column in enumerate(part_change_list):
    ax[i].scatter(combined_total[column], combined_total[sat_act_list[i]]) # scatterplot
    ax[i].plot([0,1],[1,0], transform=ax[i].transAxes, color='red', linestyle='dotted', label = 'Correlation') # Correlation line
    ax[i].set_title(titles_list[i]) # set title
    ax[i].legend(loc = 'upper center', fontsize = 12) # set legend
    ax[i].set_xlabel(xlabels_list[i]) # set label of x-axislinestyle='dotted', 
    ax[i].set_ylabel(ylabels_list[i]); # set label of y-axis
  
plt.savefig('./graphs/SAT Participation Rate Changes versus ACT Participation Rate.jpg')

# %% [markdown]
# **Interpretation**
#
# *From the scatter plots above, and the red horizontal correlation line, there does not seem to be any obvious correlation between the ACT Participation Rate of a year impacting the difference in Participation Rates of that year and the next.*

# %%
sat_act_list = ['act_comp_17', 'act_comp_18']
part_change_list = ['sat_part_17_to_18', 'sat_part_18_to_19']
titles_list = ['SAT Participation Rate Change from 2017 to 2018 versus ACT Composite Score for 2017', 
               'SAT Participation Rate Change from 2018 to 2019 versus ACT Composite Score for 2018']
xlabels_list = ['SAT Participation Rate Change from 2017 to 2018', 'SAT Participation Rate Change from 2018 to 2019']
ylabels_list = ['ACT Composite Score for 2017', 'ACT Composite Score for 2018']

# Plotting the scatter plot of the ACT Participation Rate versus the Change in SAT Participation Rate 
fig, ax = plt.subplots(2, 1, figsize = (16, 12)) # determine number of subplots and figure size of plot
ax = ax.ravel() # turns into a flattened array for iteration.

for i, column in enumerate(part_change_list):
    ax[i].scatter(combined_total[column], combined_total[sat_act_list[i]]) # scatterplot
    ax[i].plot([0,1],[1,0], transform=ax[i].transAxes, color='red', linestyle='dotted', label = 'Correlation') # Correlation line
    ax[i].set_title(titles_list[i]) # set title
    ax[i].legend(loc = 'upper center', fontsize = 12) # set legend
    ax[i].set_xlabel(xlabels_list[i]) # set label of x-axis
    ax[i].set_ylabel(ylabels_list[i]); # set label of y-axis
    
plt.savefig('./graphs/SAT Participation Rate Changes versus ACT Composite Score.jpg')

# %% [markdown]
# **Interpretation**
#
# *From the scatter plots above, and the red horizontal correlation line, there does not seem to be any obvious correlation between the ACT Composite Score of a year impacting the difference in Participation Rates of that year and the next.*

# %%
# Looking at the states with the drastic increase in the SAT Participation Rate
display(combined_total[['state','sat_part_17', 'sat_part_18', 'sat_part_17_to_18','act_part_17']].sort_values('sat_part_17_to_18', ascending = False).head())
display(combined_total[['state','sat_part_18', 'sat_part_19', 'sat_part_18_to_19','act_part_18']].sort_values('sat_part_18_to_19', ascending = False).head())
# Out:
#             state  sat_part_17  sat_part_18  sat_part_17_to_18  act_part_17
# 13       Illinois         0.09         0.99               0.90         0.93
# 5        Colorado         0.11         1.00               0.89         1.00
# 39   Rhode Island         0.71         0.97               0.26         0.21
# 48  West Virginia         0.14         0.28               0.14         0.69
# 30     New Jersey         0.70         0.82               0.12         0.34
#              state  sat_part_18  sat_part_19  sat_part_18_to_19  act_part_18
# 48   West Virginia         0.28         0.99               0.71         0.65
# 9          Florida         0.56         1.00               0.44         0.66
# 36        Oklahoma         0.08         0.22               0.14         1.00
# 40  South Carolina         0.55         0.68               0.13         1.00
# 20        Maryland         0.76         0.82               0.06         0.31

# %% [markdown]
# **Interpretation**
#
# *From the above, we can see that the states of Illinois, Colorado, West Virginia and Florida have near 100% Participation Rates since the introduction of the new SAT format.*
#
# *Through news source available to the public, we can see that for the states of Illinois, Colorado and West Virginia, they have made the switch from ACT to SAT compulsory, making SAT a must to take for the college entrance exam. Whereas in the case of Florida, the fact that many Florida schools have made it free to take the SAT has boosted the participation rates.*
#
# *Thus, judging from these, the methods in order to boost participation rates are as follows:*
# - *Working with the states to make SAT the compulsory test to take*
# - *Working with the schools in the states in order to make SAT the more accessible test compared to ACT*
# - *Covering all or part of the costs for taking the SAT test*
#
# *Information taken from*:
# - Illinois: https://www.chicagotribune.com/news/ct-illinois-chooses-sat-met-20160211-story.html
# - Colorado: https://co.chalkbeat.org/2015/12/23/21092477/goodbye-act-hello-sat-a-significant-change-for-colorado-high-schoolers
# - Colorado: https://www.coloradokids.org/wp-content/uploads/2016/01/ACTvsSAT_FINAL.pdf
# - West Virginia: https://www.wvgazettemail.com/news/education/wv-chooses-sat-as-new-high-school-standardized-test-for-juniors/article_b60d2618-4943-56f6-b180-4b4442172ef8.html
# - Florida: https://www.orlandosentinel.com/news/education/os-ne-sat-scores-florida-20190924-2ycpuogc2ndkrkwzdrkrjgrg64-story.html

# %%
# Looking at the states with low SAT Participation Rate in 2017, 2018, 2019
display(combined_total[['state', 'sat_part_17', 'act_part_17', 'sat_part_18']].sort_values('sat_part_17').head())
display(combined_total[['state', 'sat_part_18', 'act_part_18', 'sat_part_19']].sort_values('sat_part_18').head())
display(combined_total[['state', 'sat_part_19', 'act_part_19']].sort_values('sat_part_19').head())
# Out:
#            state  sat_part_17  act_part_17  sat_part_18
# 34  North Dakota         0.02         0.98         0.02
# 24   Mississippi         0.02         1.00         0.03
# 15          Iowa         0.02         0.67         0.03
# 25      Missouri         0.03         1.00         0.04
# 44          Utah         0.03         1.00         0.04
#            state  sat_part_18  act_part_18  sat_part_19
# 34  North Dakota         0.02         0.98         0.02
# 50       Wyoming         0.03         1.00         0.03
# 41  South Dakota         0.03         0.77         0.03
# 27      Nebraska         0.03         1.00         0.03
# 49     Wisconsin         0.03         1.00         0.03
#            state  sat_part_19  act_part_19
# 34  North Dakota         0.02         0.96
# 50       Wyoming         0.03         1.00
# 41  South Dakota         0.03         0.75
# 27      Nebraska         0.03         1.00
# 49     Wisconsin         0.03         1.00

# %% [markdown]
# **Observations**
#
# *Our aim to improve the Participation Rates can be done through getting in touch with those states with low participation rates.*
#
# *However it is shown earlier that the Participation Rates of the SAT and ACT are inversely correlated, and from the source below regarding the states with high Participation in ACT, it will be better to not choose states that made it compulsory to take ACT in order for our measures to be more cost-effective.*
#
# *As such, we would be choosing those states with less than 75% Participation Rate in ACT as these states would be more receptive towards aid by the College Board.*
#
# *Information taken from*:
# - States requiring ACT: https://blog.prepscholar.com/which-states-require-the-act-full-list-and-advice

# %%
display(combined_total[combined_total['act_part_17'] < 0.75][['state', 'sat_part_17', 'act_part_17', 'sat_part_18']].sort_values('sat_part_17').head())
display(combined_total[combined_total['act_part_17'] < 0.75][['state', 'sat_part_18', 'act_part_18', 'sat_part_19']].sort_values('sat_part_18').head())
display(combined_total[combined_total['act_part_17'] < 0.75][['state', 'sat_part_19', 'act_part_19']].sort_values('sat_part_19').head())
# Out:
#             state  sat_part_17  act_part_17  sat_part_18
# 15           Iowa         0.02         0.67         0.03
# 16         Kansas         0.04         0.73         0.04
# 31     New Mexico         0.11         0.66         0.16
# 48  West Virginia         0.14         0.69         0.28
# 2         Arizona         0.30         0.62         0.29
#             state  sat_part_18  act_part_18  sat_part_19
# 15           Iowa         0.03         0.68         0.03
# 16         Kansas         0.04         0.71         0.04
# 31     New Mexico         0.16         0.67         0.18
# 48  West Virginia         0.28         0.65         0.99
# 2         Arizona         0.29         0.66         0.31
#          state  sat_part_19  act_part_19
# 15        Iowa         0.03         0.66
# 16      Kansas         0.04         0.72
# 31  New Mexico         0.18         0.63
# 2      Arizona         0.31         0.73
# 1       Alaska         0.41         0.38

# %% [markdown]
# **Interpretation**
#
# *From above, we can see that the states of Iowa, Kansas, New Mexico and Arizona have low SAT Participation Rates while not having ACT Participation Rates of less than 75% across the years 2017 to 2019.*
#
# *As such, these states would be our targets for aid by the College Board in order to accomplish our aim of boosting the participation rates.*
#
# *Do note that West Virginia is not chosen as it has made it compulsory to take SAT in 2019, and Alaska is not selected for now since the overall takeup rates for both the SAT and ACT are low so there may be more issues to approach for the state.*

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are your key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **Key takeaways:**
#
# 1. *The Participation Rates for the SAT and ACT are inversely correlated, as such, when looking at the states with low SAT Participation Rates, these states will be likely to have high ACT Participation Rates.*
# 2. *There appears to be no relation between the current year's ACT Participation Rate to the Change in SAT Participation Rate from the current year to the next. As such we cannot use this to identify trends relating to how the Participation Rate will change from year to year.*
# 3. *Regarding the states with high ACT Participation Rates, as those states with near 100% ACT Participation Rates have made it compulsory to take ACT, our target states would have to shy away from these as it will be less cost-effective to do so. Taking this into account, our target states chosen for aid by the College Board would be Iowa, Kansas, New Mexico and Arizona as these states have low SAT Participation Rates while not having very high ACT Participation Rates.*
#
# **Recommendations:**
#
# *By taking a look at the states with the drastic increases in SAT Participation Rates, we discover that these states either just made it compulsory to take the SAT or made it more accessible to the students through various policies. Judging from these successes in increasing the SAT Participation Rates, our recommendations will be as follows:*
# - *Our targeted states for aid would be Iowa, Kansas, New Mexico and Arizona*
#   1. *Working with the states to make SAT the compulsory test to take*
#   2. *Working with the schools in the states in order to make SAT the more accessible test compared to ACT*
#   3. *Covering all or part of the costs for taking the SAT test*

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
